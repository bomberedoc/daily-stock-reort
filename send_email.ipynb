# %%
# !pip install yfinance
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 10.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    --------- ------------------------------ 2.9/12.3 MB 13.9 MB/s eta 0:00:01
#    ------------------- -------------------- 6.0/12.3 MB 14.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.3 MB 14.1 MB/s eta 0:00:01
# ...

# %%
import yfinance as yf
import pandas as pd
import os
from datetime import datetime
import pytz

# %%
data = yf.download(["AAPL","WDC","MA"],period="1d",interval="1d",auto_adjust=True,progress=False)

# %%
data
# Out:
# Price            Close                                High             \
# Ticker            AAPL          MA         WDC        AAPL         MA
# Date
# 2026-02-27  264.179993  517.210022  279.700012  272.809998  518.76001
#
# Price                          Low                            Open  \
# Ticker             WDC        AAPL      MA         WDC        AAPL
# Date
# 2026-02-27  287.829987  262.890015  506.75  274.100006  272.809998
#
# Price                                 Volume
# Ticker              MA         WDC      AAPL       MA      WDC
# Date
# 2026-02-27  509.470001  275.799988  72239400  5121100  9890800
